# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/"ML(PG) Project"
# Out:
# /content/drive/MyDrive/ML(PG) Project

# %%
# !nvidia-smi
# Out:
# Thu Dec  9 15:20:03 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 495.44       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   48C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python3 train_neural_ode_generator.py --num_workers 2 --target_market "NASDAQ" --num_epochs 150
# Out:
# 100% 150/150 [19:14<00:00,  7.70s/it]

# %%
# !python3 test_gen.py --num_workers 2 --target_market "NASDAQ"
# Out:
# 5218.859863000001
# 0.6730342
# 0.6773782
# 1.0902551
# 1.3008819
# 341682.12
# MSE on NASDAQ, RMSE: 2251.247538776767, MAE:2177.417670618688, R-Squared:-13.832837628975915

# %%
# !python3 train_neural_ode_generator.py --num_workers 2 --target_market "NYSE" --num_epochs 150
# Out:
# 100% 150/150 [20:18<00:00,  8.12s/it]

# %%
# !python3 test_gen.py --num_workers 2 --target_market "NYSE"
# Out:
# 11239.660156
# 0.78221333
# 0.78222805
# 1.0011747
# 1.1059515
# 388508.06
# MSE on NYSE, RMSE: 2538.7777998561533, MAE:2461.0520894271654, R-Squared:-15.590113151235954

# %%
# !python3 train_neural_ode_generator.py --num_workers 2 --target_market "S&P" --num_epochs 150
# Out:
# 100% 150/150 [19:48<00:00,  7.93s/it]

# %%
# !python3 test_gen.py --num_workers 2 --target_market "S&P"
# Out:
# 2130.820068
# 0.7035449
# 0.70723104
# 1.0788759
# 1.2175499
# 24420.324
# MSE on S&P, RMSE: 815.964501319298, MAE:799.7626671049919, R-Squared:-26.26409614586726

# %%
# !python3 train_neural_ode_generator.py --num_workers 2 --target_market "DJI" --num_epochs 150
# Out:
# 100% 150/150 [19:30<00:00,  7.80s/it]

# %%
# !python3 test_gen.py --num_workers 2 --target_market "DJI"
# Out:
# 18312.390625
# 0.6969672
# 0.7127965
# 1.0949936
# 1.286744
# 2980330.8
# MSE on DJI, RMSE: 7455.720708609541, MAE:7288.813402490225, R-Squared:-17.651544391436808

# %%
# !python3 train_neural_ode_generator.py --num_workers 2 --target_market "RUSSELL" --num_epochs 150
# Out:
# 100% 150/150 [19:55<00:00,  7.97s/it]

# %%
# !python3 test_gen.py --num_workers 2 --target_market "RUSSELL"
# Out:
# 1295.800049
# -0.019699132
# -0.00975582
# 1.0227315
# 1.1669161
# 12414.374
# MSE on RUSSELL, RMSE: 1355.8988825457097, MAE:1350.7816734412381, R-Squared:-147.09137989703007

# %%
# !python3 train.py --num_workers 2 --model_save "New_Models/NASDAQ_ODE_Sing.pt" --target_market "NASDAQ" --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/NYSE_ODE_Sing.pt" --target_market "NYSE" --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/S&P_ODE_Sing.pt" --target_market "S&P" --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/RUSSELL_ODE_Sing.pt" --target_market "RUSSELL" --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/DJI_ODE_Sing.pt" --target_market "DJI" --num_epochs 15

# %%
# !python3 eval.py --num_workers 2 --model_save "New_Models/NASDAQ_ODE_Sing.pt" --target_market "NASDAQ"
# !python3 eval.py --num_workers 2 --model_save "New_Models/NYSE_ODE_Sing.pt" --target_market "NYSE"
# !python3 eval.py --num_workers 2 --model_save "New_Models/S&P_ODE_Sing.pt" --target_market "S&P"
# !python3 eval.py --num_workers 2 --model_save "New_Models/RUSSELL_ODE_Sing.pt" --target_market "RUSSELL"
# !python3 eval.py --num_workers 2 --model_save "New_Models/DJI_ODE_Sing.pt" --target_market "DJI"
# Out:
# Testing: 100% 4/4 [00:00<00:00,  4.28it/s]
# Average accuracy for NASDAQ input on All Markets as False: 0.4987405541561713
# Average f-score for NASDAQ input on All Markets as False: 0.4796717446141484
# Max f-score for NASDAQ input on All Markets as False: 0.5792811839323467
# Testing: 100% 4/4 [00:00<00:00,  5.13it/s]
# Average accuracy for NYSE input on All Markets as False: 0.5340050377833753
# Average f-score for NYSE input on All Markets as False: 0.5313287686093332
# Max f-score for NYSE input on All Markets as False: 0.5667447306791569
# Testing: 100% 4/4 [00:00<00:00,  5.71it/s]
# Average accuracy for S&P input on All Markets as False: 0.5566750629722922
# Average f-score for S&P input on All Markets as False: 0.5428661153564326
# Max f-score for S&P input on All Markets as False: 0.6223175965665236
# Testing: 100% 4/4 [00:00<00:00,  5.89it/s]
# Average accuracy for RUSSELL input on All Markets as False: 0.5264483627204031
# ...

# %%
# !python3 train.py --num_workers 2 --model_save "New_Models/NASDAQ_ODE_Multi.pt" --target_market "NASDAQ" --all_markets --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/NYSE_ODE_Multi.pt" --target_market "NYSE" --all_markets --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/S&P_ODE_Multi.pt" --target_market "S&P" --all_markets --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/RUSSELL_ODE_Multi.pt" --target_market "RUSSELL" --all_markets --num_epochs 15
# !python3 train.py --num_workers 2 --model_save "New_Models/DJI_ODE_Multi.pt" --target_market "DJI" --all_markets --num_epochs 15

# %%
# !python3 eval.py --num_workers 2 --model_save "New_Models/NASDAQ_ODE_Multi.pt" --target_market "NASDAQ" --all_markets
# !python3 eval.py --num_workers 2 --model_save "New_Models/NYSE_ODE_Multi.pt" --target_market "NYSE" --all_markets
# !python3 eval.py --num_workers 2 --model_save "New_Models/S&P_ODE_Multi.pt" --target_market "S&P" --all_markets
# !python3 eval.py --num_workers 2 --model_save "New_Models/RUSSELL_ODE_Multi.pt" --target_market "RUSSELL" --all_markets
# !python3 eval.py --num_workers 2 --model_save "New_Models/DJI_ODE_Multi.pt" --target_market "DJI" --all_markets
# Out:
# Testing: 100% 4/4 [00:00<00:00,  4.08it/s]
# Average accuracy for NASDAQ input on All Markets as True: 0.4609571788413098
# Average f-score for NASDAQ input on All Markets as True: 0.4387320966122298
# Max f-score for NASDAQ input on All Markets as True: 0.5504201680672268
# Testing: 100% 4/4 [00:00<00:00,  4.09it/s]
# Average accuracy for NYSE input on All Markets as True: 0.5743073047858942
# Average f-score for NYSE input on All Markets as True: 0.5668764726768019
# Max f-score for NYSE input on All Markets as True: 0.6236080178173721
# Testing: 100% 4/4 [00:00<00:00,  4.56it/s]
# Average accuracy for S&P input on All Markets as True: 0.5415617128463476
# Average f-score for S&P input on All Markets as True: 0.5410696138211382
# Max f-score for S&P input on All Markets as True: 0.5560975609756097
# Testing: 100% 4/4 [00:00<00:00,  4.67it/s]
# Average accuracy for RUSSELL input on All Markets as True: 0.491183879093199
# ...

# %%
# !python3 train.py --num_workers 2 --model_save "New_Models/NASDAQ_ODE_reg.pt" --target_market "NASDAQ" --num_epochs 10 --regression
# !python3 train.py --num_workers 2 --model_save "New_Models/NYSE_ODE_reg.pt" --target_market "NYSE" --num_epochs 10 --regression
# !python3 train.py --num_workers 2 --model_save "New_Models/S&P_ODE_reg.pt" --target_market "S&P" --num_epochs 10 --regression
# !python3 train.py --num_workers 2 --model_save "New_Models/RUSSELL_ODE_reg.pt" --target_market "RUSSELL" --num_epochs 10 --regression
# !python3 train.py --num_workers 2 --model_save "New_Models/DJI_ODE_reg.pt" --target_market "DJI" --num_epochs 10 --regression

# %%
# !python3 eval.py --num_workers 2 --model_save "New_Models/NASDAQ_ODE_reg.pt" --target_market "NASDAQ" --regression
# !python3 eval.py --num_workers 2 --model_save "New_Models/NYSE_ODE_reg.pt" --target_market "NYSE" --regression
# !python3 eval.py --num_workers 2 --model_save "New_Models/S&P_ODE_reg.pt" --target_market "S&P" --regression
# !python3 eval.py --num_workers 2 --model_save "New_Models/RUSSELL_ODE_reg.pt" --target_market "RUSSELL" --regression
# !python3 eval.py --num_workers 2 --model_save "New_Models/DJI_ODE_reg.pt" --target_market "DJI" --regression
