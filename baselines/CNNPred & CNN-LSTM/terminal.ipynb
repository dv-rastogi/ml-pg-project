# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/"ML(PG) Project"
# Out:
# /content/drive/MyDrive/ML(PG) Project

# %%
# !nvidia-smi
# Out:
# Fri Oct  8 11:33:07 2021
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 470.74       Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8    26W / 149W |      0MiB / 11441MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !python3 train.py --num_workers 4 --model_save "Models/NASDAQ_Sing.pt" --target_market "NASDAQ" --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/NYSE_Sing.pt" --target_market "NYSE" --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/S&P_Sing.pt" --target_market "S&P" --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/RUSSELL_Sing.pt" --target_market "RUSSELL" --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/DJI_Sing.pt" --target_market "DJI" --num_epochs 100
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training Epoch 1:   0% 0/12 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Training Epoch 1: 100% 12/12 [00:00<00:00, 12.17it/s]
# ...

# %%
# !python3 eval.py --num_workers 4 --model_save "Models/NASDAQ_Sing.pt" --target_market "NASDAQ"
# !python3 eval.py --num_workers 4 --model_save "Models/NYSE_Sing.pt" --target_market "NYSE"
# !python3 eval.py --num_workers 4 --model_save "Models/S&P_Sing.pt" --target_market "S&P"
# !python3 eval.py --num_workers 4 --model_save "Models/RUSSELL_Sing.pt" --target_market "RUSSELL"
# !python3 eval.py --num_workers 4 --model_save "Models/DJI_Sing.pt" --target_market "DJI"
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# F
# Testing:   0% 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Testing: 100% 4/4 [00:00<00:00, 10.30it/s]
# ...

# %%
# !python3 train.py --num_workers 4 --model_save "Models/NASDAQ_Multi.pt" --target_market "NASDAQ" --all_markets --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/NYSE_Multi.pt" --target_market "NYSE" --all_markets --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/S&P_Multi.pt" --target_market "S&P" --all_markets --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/RUSSELL_Multi.pt" --target_market "RUSSELL" --all_markets --num_epochs 100
# !python3 train.py --num_workers 4 --model_save "Models/DJI_Multi.pt" --target_market "DJI" --all_markets --num_epochs 100
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training Epoch 1:   0% 0/12 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Training Epoch 1: 100% 12/12 [00:01<00:00,  6.36it/s]
# ...

# %%
# !python3 eval.py --num_workers 4 --model_save "Models/NASDAQ_Multi.pt" --target_market "NASDAQ" --all_markets
# !python3 eval.py --num_workers 4 --model_save "Models/NYSE_Multi.pt" --target_market "NYSE" --all_markets
# !python3 eval.py --num_workers 4 --model_save "Models/S&P_Multi.pt" --target_market "S&P" --all_markets
# !python3 eval.py --num_workers 4 --model_save "Models/RUSSELL_Multi.pt" --target_market "RUSSELL" --all_markets
# !python3 eval.py --num_workers 4 --model_save "Models/DJI_Multi.pt" --target_market "DJI" --all_markets
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# F
# Testing:   0% 0/4 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:718: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at  /pytorch/c10/core/TensorImpl.h:1156.)
#   return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
# Testing: 100% 4/4 [00:00<00:00,  5.99it/s]
# ...

# %%
# !python3 train.py --num_workers 4 --model_save "Models/NASDAQ_reg.pt" --target_market "NASDAQ" --num_epochs 100 --regression
# !python3 train.py --num_workers 4 --model_save "Models/NYSE_reg.pt" --target_market "NYSE" --num_epochs 100 --regression
# !python3 train.py --num_workers 4 --model_save "Models/S&P_reg.pt" --target_market "S&P" --num_epochs 100 --regression
# !python3 train.py --num_workers 4 --model_save "Models/RUSSELL_reg.pt" --target_market "RUSSELL" --num_epochs 100 --regression
# !python3 train.py --num_workers 4 --model_save "Models/DJI_reg.pt" --target_market "DJI" --num_epochs 100 --regression
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Training Epoch 1: 100% 12/12 [00:00<00:00, 15.28it/s]
# Training Epoch 2: 100% 12/12 [00:00<00:00, 14.35it/s]
# Training Epoch 3: 100% 12/12 [00:00<00:00, 14.91it/s]
# Training Epoch 4: 100% 12/12 [00:00<00:00, 14.61it/s]
# Training Epoch 5: 100% 12/12 [00:00<00:00, 14.66it/s]
# Training Epoch 6: 100% 12/12 [00:00<00:00, 14.84it/s]
# Training Epoch 7: 100% 12/12 [00:00<00:00, 14.77it/s]
# Training Epoch 8: 100% 12/12 [00:00<00:00, 15.12it/s]
# Training Epoch 9: 100% 12/12 [00:00<00:00, 14.97it/s]
# ...

# %%
# !python3 eval.py --num_workers 4 --model_save "Models/NASDAQ_reg.pt" --target_market "NASDAQ" --regression
# !python3 eval.py --num_workers 4 --model_save "Models/NYSE_reg.pt" --target_market "NYSE" --regression
# !python3 eval.py --num_workers 4 --model_save "Models/S&P_reg.pt" --target_market "S&P" --regression
# !python3 eval.py --num_workers 4 --model_save "Models/RUSSELL_reg.pt" --target_market "RUSSELL" --regression
# !python3 eval.py --num_workers 4 --model_save "Models/DJI_reg.pt" --target_market "DJI" --regression
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# F
# Testing: 100% 4/4 [00:00<00:00, 11.19it/s]
# MSE on NASDAQ, RMSE: 854.8889117730289, MAE:645.2132858795843, R-Squared:0.9999976776965235
# ...
